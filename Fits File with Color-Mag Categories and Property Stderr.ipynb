# %% [markdown]
# # New Fits File with the Color-Magnitude Categories and Property Errors
#
# ### For the Red Seq., Blue Cloud, Green Valley Categories and Error values for the HyperFits

# %%
#import astropy
from astropy.io import fits

from astropy.table import Table

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from astropy.table import Table, join

# %%
#Reading in data file

fits_NSA_file = r"C:\Users\caeho\OneDrive\Documents\University of Rochester REU\NSA_v1_0_1_VAGC_CMDJan2020_vflag-V2-VF.fits"   #r'C:\Users\caeho\OneDrive\Documents\University of Rochester REU\NSA_v1_0_1_VAGC_vflag-V2-VF.fits'
#data = r'C:\Users\caeho\OneDrive\Documents\University of Rochester REU\NSA_v1_0_1_VAGC_vflag-V2-VF.fits'

hdul = fits.open(fits_NSA_file)

# %%
hdul.info()
# Out:
# Filename: C:\Users\caeho\OneDrive\Documents\University of Rochester REU\NSA_v1_0_1_VAGC_CMDJan2020_vflag-V2-VF.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU    368   641409R x 148C   [19A, 27A, D, D, J, J, J, J, J, J, E, E, 7A, E, I, B, I, 3A, E, E, J, E, 7E, 7E, I, 7E, 7E, 7E, 7E, 7E, 5E, 7E, E, E, E, E, D, D, 7B, 105E, 105E, 105E, 105E, 105E, 105E, 7E, 7E, 7E, 7E, E, E, E, E, 7E, 7E, E, E, E, 7E, 7E, 7J, J, J, 8A, 15E, E, E, E, E, J, I, J, D, D, E, 6A, 27A, 8A, J, D, D, E, E, E, E, E, E, E, E, 7E, 7E, 7E, 7E, E, 7E, 7E, 7E, 7E, I, 7E, 7E, 7E, 7E, 5E, E, 7E, E, E, E, D, D, D, D, K, K, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, K, K, E, E, E, K, K, D, D]

# %%
# Names of all the collumns in the data base

data_header = hdul[1].header
data_header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4135 / length of dimension 1
# NAXIS2  =               641409 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                  148 / number of table fields
# TTYPE1  = 'IAUNAME '
# TFORM1  = '19A     '
# TTYPE2  = 'SUBDIR  '
# TFORM2  = '27A     '
# TTYPE3  = 'RA      '
# TFORM3  = 'D       '
# TTYPE4  = 'DEC     '
# TFORM4  = 'D       '
# TTYPE5  = 'ISDSS   '
# TFORM5  = 'J       '
# TNULL5  =               999999
# TTYPE6  = 'INED    '
# TFORM6  = 'J       '
# TNULL6  =               999999
# TTYPE7  = 'ISIXDF  '
# TFORM7  = 'J       '
# TNULL7  =               999999
# TTYPE8  = 'IALFALFA'
# TFORM8  = 'J       '
# TNULL8  =               999999
# TTYPE9  = 'IZCAT   '
# ...

# %%
data = hdul[1].data

# %%
data_table = Table()

data_table['u_r_err'] = data['u_r_err']
data_table['sSFR_err'] = data['sSFR_err']
data_table['CMD_class'] = data['CMD_class']
data_table['ELPETRO_AMIVAR_r'] = data['ELPETRO_AMIVAR'][:,4]

data_table['ID'] = [i for i in range(len(data_table))]


#data_table[''] = data['']

# %%
data_table
# Out:
# <Table length=641409>
#   u_r_err        sSFR_err      CMD_class ELPETRO_AMIVAR_r   ID
#   float32        float64         int64       float32      int32
# ----------- ------------------ --------- ---------------- ------
# 0.019882048                nan       -99        2487.7773      0
#  0.19388361  1.169804573059082         2        2198.1165      1
#  0.10183159                nan       -99        1406.6729      2
#  0.22052868 1.3031730651855469         3        128.33977      3
#  0.22563264                nan       -99        1161.7567      4
#  0.26438314 0.9607744216918945         3        1857.8073      5
#  0.32652387 1.4206018447875977         2        1554.4117      6
#  0.10809134 0.5014019012451172         1        2048.2756      7
#    0.719762 0.7408857345581055        -1        122.73205      8
#  0.20802997                nan       -99        2219.2703      9
#         ...                ...       ...              ...    ...
# ...

# %%
data_table.write('errors_CMD_table.txt', format = 'ascii.commented_header', overwrite = True)
