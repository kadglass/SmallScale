# %% [markdown]
# # Groups: 2D Virial Distance Properties Plots
#
# ### Importing Tables

# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt


import matplotlib as mpl
import matplotlib.pyplot as plt

from scipy.stats import binned_statistic

import seaborn as sns

# %%
dwarf_table = Table.read('g_dwarf_table.txt', format = 'ascii.commented_header')
dwarf_table[:5]
# Out:
# <Table length=5>
#   aimc  IN_DR7_LSS         RA         ... 3D_group_ID_vir 3D_group_dist_vir
# float64  float64        float64       ...      int32           float64
# ------- ---------- ------------------ ... --------------- ------------------
#     0.0        1.0 147.17645340393182 ...            2539  41.76447666154416
#  106.68        1.0 146.85676432411947 ...            4270 1.3749647386881871
#     0.0        1.0 146.19277353258968 ...            2539  48.37100908551739
#  199.39        1.0 146.00780426178756 ...            2539 46.289567183583294
#     0.0        1.0  146.6190367018052 ...            2539  42.50789399533266

# %%
t3mask = dwarf_table['t3'] < 3  # Makes a boolean selection mask (numpy array)
dwarf_t3= dwarf_table[t3mask]

# %%
# Separating into Void, Wall, or Other Dwarf Galaxies

dwarf_wall = dwarf_table['vflag_VF']==0
dwarf_void = dwarf_table['vflag_VF']==1
dwarf_other = ~(dwarf_wall | dwarf_void)


dwarf_wall_t3 = dwarf_t3['vflag_VF']==0
dwarf_void_t3 = dwarf_t3['vflag_VF']==1
dwarf_other_t3 = ~(dwarf_wall_t3 | dwarf_void_t3)

# %% [markdown]
# ## Profile Histogram Function

# %%
def profilehist(x, y, w=None, bins=10, uncertainty='stderr'):
    """Compute a profile histogram given x, y and optional weights.
    
    Parameters
    ----------
    x : (N,) array_like
        Sequence of values to be binned.
    y : (N,) array_like
        Data on which the statistic will be computed.
    w : None or (N,) array_like
        Weights for each data point y.
    bins : int or array_like
        If int, define equal-length bins given by data min/max range; else, user-defined bin edges.
    uncertainty : str
        'stderr' to compute standard error on the mean; 'sample' for sample uncertainty
        
    Returns
    -------
    xc : array of dtype float
        Bin centers in x.
    yavg : array of dtype float
        Average in each bin.
    yerr : array of dtype float
        Uncertainty in each bin (sample error or error on the mean).
    """
    # Default to equal weights in each bin.
    if w is None:
        w = np.ones_like(y, dtype=np.float64)

    # Compute weighted sums and construct the weighted means and uncertainties.
    (Y, E, W), edges, idx = binned_statistic(x, [w*y, w*y**2, w], bins=bins, statistic='sum')
    yavg = Y/W
    ystd = np.sqrt(E/W - yavg**2)
    yerr = ystd/np.sqrt(W)

    # Compute bin centers.
    xc = 0.5*(edges[1:] + edges[:-1])
    
    if uncertainty == 'sample':
        return xc, yavg, ystd
    elif uncertainty == 'stderr':
        return xc, yavg, yerr
    else:
        raise ValueError(f'uncertainty={uncertainty} unknown; allowed: "stderr" and "sample"')

# %% [markdown]
# # Profile Historgrams and Linear Regressions

# %% [markdown]
# ## Color (u-r

# %% [markdown]
# ### Profile Histogram

# %%
sfd = dwarf_table['BPTclass'] == 1
sfd_t3 = dwarf_t3['BPTclass'] == 1

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)
plt.rcParams.update({'font.size': 14})
for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    #d = dwarf_table['2D_group_dist_vir_h'][select & sfd]
    #vals = dwarf_table['u_r'][select & sfd]
    
    d = dwarf_table['2D_group_dist_vir'][select]
    vals = dwarf_table['u_r'][select]
    
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,2,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    #ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)
    
    ax.plot(xc, yavg, c, label = label )
    ax.fill_between([0, *xc, 2], 
                   np.array([yavg[0], *yavg, yavg[-1]]) + np.array([yerr[0], *yerr, yerr[-1]]),
                   np.array([yavg[0], *yavg, yavg[-1]]) - np.array([yerr[0], *yerr, yerr[-1]]),
                   color = c, alpha = 0.15)

    ax.set(xlabel='Distance to Nearest Neighbor [$r^{-1}_{vir}]$', ylabel='u-r', xlim=([0,2]), ylim=([0.5,2.5]));
    ax.legend();

    #fig.savefig('group_sfd_ur_2D_vir_PH.png')
    
    #fig.savefig('group_ur_2D_vir_PH.png')

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)
plt.rcParams.update({'font.size': 14})
for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    #d = dwarf_table['2D_group_dist_vir_h'][select & sfd]
    #vals = dwarf_table['u_r'][select & sfd]
    
    d = dwarf_table['2D_group_dist_vir'][select]
    vals = dwarf_table['u_r'][select]
    
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    xedges = np.linspace(0,2,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$r^{-1}_{vir}]$', ylabel='u-r', xlim=(0,2), ylim=(0.5,2.5));
        
    ax.legend()
        
    #fig.savefig('group_sfd_ur_2D_vir_LR.png')
    
    #fig.savefig('group_ur_2D_vir_LR.png')

# %% [markdown]
# ## Star Formation Rate (sSFR)

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)
plt.rcParams.update({'font.size': 14})
for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    #d = dwarf_table['2D_group_dist_vir'][select & sfd]
    #vals = dwarf_table['sSFR'][select & sfd]
    
    d = dwarf_table['2D_group_dist_vir'][select]
    vals = dwarf_table['sSFR'][select]
    
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,2,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    #ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)
    
    ax.plot(xc, yavg, c, label = label )
    ax.fill_between([0, *xc, 2], 
                   np.array([yavg[0], *yavg, yavg[-1]]) + np.array([yerr[0], *yerr, yerr[-1]]),
                   np.array([yavg[0], *yavg, yavg[-1]]) - np.array([yerr[0], *yerr, yerr[-1]]),
                   color = c, alpha = 0.15)

    ax.set(xlabel='Distance to Nearest Neighbor [$r^{-1}_{vir}]$', ylabel='sSFR [$yr^{-1}]$', xlim=([0,2]), ylim=(-11,-8.5));
    ax.legend();

    #fig.savefig('group_sfd_sSFR_2D_vir_PH.png')
    
    #fig.savefig('group_sSFR_2D_vir_PH.png')

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)
plt.rcParams.update({'font.size': 14})
for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    #d = dwarf_table['2D_group_dist_vir'][select & sfd]
    #vals = dwarf_table['sSFR'][select & sfd]
    
    d = dwarf_table['2D_group_dist_vir'][select]
    vals = dwarf_table['sSFR'][select]
    
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    xedges = np.linspace(0,2,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$r^{-1}_{vir}]$', ylabel='sSFR [$yr^{-1}]$', xlim=(0,2), ylim=(-11,-8.5));
        
    ax.legend()
        
    #fig.savefig('group_sfd_sSFR_2D_vir_LR.png')
    
    #fig.savefig('group_sSFR_2D_vir_LR.png')

# %% [markdown]
# ## Metallicity (12 + log(O/H))

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)
plt.rcParams.update({'font.size': 14})
for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    #d = dwarf_t3['2D_group_dist_vir'][select & sfd_t3]
    #vals = dwarf_t3['Z12logOH'][select & sfd_t3]
    
    d = dwarf_t3['2D_group_dist_vir'][select]
    vals = dwarf_t3['Z12logOH'][select]
    
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,2,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    #ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)
    
    ax.plot(xc, yavg, c, label = label )
    ax.fill_between([0, *xc, 2], 
                   np.array([yavg[0], *yavg, yavg[-1]]) + np.array([yerr[0], *yerr, yerr[-1]]),
                   np.array([yavg[0], *yavg, yavg[-1]]) - np.array([yerr[0], *yerr, yerr[-1]]),
                   color = c, alpha = 0.15)

    ax.set(xlabel='Distance to Nearest Neighbor [$r^{-1}_{vir}]$', ylabel='12 + log(O/H)', xlim=([0,2]), ylim=(6.5,9));
    ax.legend();

    #fig.savefig('group_sfd_Z12logOH_2D_vir_PH.png')
    
    #fig.savefig('group_Z12logOH_2D_vir_PH.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_27764\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_27764\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)
# C:\Users\caeho\AppData\Local\Temp\ipykernel_27764\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_27764\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)
plt.rcParams.update({'font.size': 14})
for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    #d = dwarf_t3['2D_group_dist_vir'][select & sfd_t3]
    #vals = dwarf_t3['Z12logOH'][select & sfd_t3]
    
    d = dwarf_t3['2D_group_dist_vir'][select]
    vals = dwarf_t3['Z12logOH'][select]
    
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    xedges = np.linspace(0,2,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$r^{-1}_{vir}]$', ylabel='12 + log(O/H)', xlim=(0,2), ylim=(7,8.7));
        
    ax.legend()
        
    #fig.savefig('group_sfd_Z12logOH_2D_vir_LR.png')
    
    #fig.savefig('group_Z12logOH_2D_vir_LR.png')

# %% [markdown]
# ## N/O Ratio

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)
plt.rcParams.update({'font.size': 14})
for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    #d = dwarf_t3['2D_group_dist_vir'][select & sfd_t3]
    #vals = dwarf_t3['logNO'][select & sfd_t3]
    
    d = dwarf_t3['2D_group_dist_vir'][select]
    vals = dwarf_t3['logNO'][select]
    
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,2,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    #ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)
    
    ax.plot(xc, yavg, c, label = label )
    ax.fill_between([0, *xc, 2], 
                   np.array([yavg[0], *yavg, yavg[-1]]) + np.array([yerr[0], *yerr, yerr[-1]]),
                   np.array([yavg[0], *yavg, yavg[-1]]) - np.array([yerr[0], *yerr, yerr[-1]]),
                   color = c, alpha = 0.15)

    ax.set(xlabel='Distance to Nearest Neighbor [$r^{-1}_{vir}]$', ylabel='log(N/O)', xlim=([0,2]), ylim=(-2,-0.8));
    ax.legend();

    #fig.savefig('group_sfd_logNO_2D_vir_PH.png')
    
    #fig.savefig('group_logNO_2D_vir_PH.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_27764\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_27764\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)
# C:\Users\caeho\AppData\Local\Temp\ipykernel_27764\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_27764\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)
plt.rcParams.update({'font.size': 14})
for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    #d = dwarf_t3['2D_group_dist_vir'][select & sfd_t3]
    #vals = dwarf_t3['logNO'][select & sfd_t3]
    
    d = dwarf_t3['2D_group_dist_vir'][select]
    vals = dwarf_t3['logNO'][select]
    
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    xedges = np.linspace(0,2,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$r^{-1}_{vir}]$', ylabel='log(N/O)', xlim=(0,2), ylim=(-2,-0.8));
        
    ax.legend()
        
    #fig.savefig('group_sfd_logNO_2D_vir_LR.png')
    
    #fig.savefig('group_logNO_2D_vir_LR.png')
