# %% [markdown]
# # 3D Distance Properties Plots
#
# ### Importing Tables

# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt


import matplotlib as mpl
import matplotlib.pyplot as plt

from scipy.stats import binned_statistic

import seaborn as sns

# %%
dwarf_table = Table.read('dwarf_table.txt', format = 'ascii.commented_header')
dwarf_table[:5]
# Out:
# <Table length=5>
#   aimc  IN_DR7_LSS ... 3D_neighbor_ID_vir 3D_neighbor_dist_vir
# float64  float64   ...       int32              float64
# ------- ---------- ... ------------------ --------------------
#     0.0        1.0 ...                208   2.3657856725525463
#  106.68        1.0 ...             585700   3.7385754919749274
#     0.0        1.0 ...             585695   2.8927174640703734
#  199.39        1.0 ...             639857    7.109919536505821
#     0.0        1.0 ...             585714    2.125689993784549

# %%
gal_table = Table.read('gal_table.txt', format = 'ascii.commented_header')
gal_table[:5]
# Out:
# <Table length=5>
#   aimc  IN_DR7_LSS         RA         ... vflag_VF  ID#  gamma_ratio
# float64  float64        float64       ...  int32   int32    int32
# ------- ---------- ------------------ ... -------- ----- -----------
#   -99.0        0.0   146.714215072841 ...        9     0           1
#     1.0        1.0  146.6285851269414 ...        2     1           2
#   -99.0        0.0 146.63170644325592 ...        2     2           1
#     1.0        1.0  146.9341288729797 ...        9     3           2
#   -99.0        1.0  146.9634997327016 ...        2     4           1

# %% [markdown]
# ## Getting values for Difference in Metallicity and N/O Ratio (Target - Neighboring)

# %%
t3mask = dwarf_table['t3'] < 3  # Makes a boolean selection mask (numpy array)
dwarf_t3= dwarf_table[t3mask]

# %%
#creating the new columns
dwarf_t3['3D_Z12logOH_diff'] = np.nan
dwarf_t3['3D_logNO_diff'] = np.nan

# %%
for i in range(len(dwarf_t3)):
    
    di = gal_table['ID#'] == dwarf_t3['3D_neighbor_ID'][i] #finding 2D neighboring galaxy in the large table
    
    dwarf_t3['3D_Z12logOH_diff'][i] = dwarf_t3['Z12logOH'][i] - gal_table['Z12logOH'][di]
    dwarf_t3['3D_logNO_diff'][i] = dwarf_t3['logNO'][i] - gal_table['logNO'][di]

# %%
# Separating into Void, Wall, or Other Dwarf Galaxies

dwarf_wall = dwarf_table['vflag_VF']==0
dwarf_void = dwarf_table['vflag_VF']==1
dwarf_other = ~(dwarf_wall | dwarf_void)


dwarf_wall_t3 = dwarf_t3['vflag_VF']==0
dwarf_void_t3 = dwarf_t3['vflag_VF']==1
dwarf_other_t3 = ~(dwarf_wall_t3 | dwarf_void_t3)

# %% [markdown]
# ## Profile Histogram Function

# %%
def profilehist(x, y, w=None, bins=10, uncertainty='stderr'):
    """Compute a profile histogram given x, y and optional weights.
    
    Parameters
    ----------
    x : (N,) array_like
        Sequence of values to be binned.
    y : (N,) array_like
        Data on which the statistic will be computed.
    w : None or (N,) array_like
        Weights for each data point y.
    bins : int or array_like
        If int, define equal-length bins given by data min/max range; else, user-defined bin edges.
    uncertainty : str
        'stderr' to compute standard error on the mean; 'sample' for sample uncertainty
        
    Returns
    -------
    xc : array of dtype float
        Bin centers in x.
    yavg : array of dtype float
        Average in each bin.
    yerr : array of dtype float
        Uncertainty in each bin (sample error or error on the mean).
    """
    # Default to equal weights in each bin.
    if w is None:
        w = np.ones_like(y, dtype=np.float64)

    # Compute weighted sums and construct the weighted means and uncertainties.
    (Y, E, W), edges, idx = binned_statistic(x, [w*y, w*y**2, w], bins=bins, statistic='sum')
    yavg = Y/W
    ystd = np.sqrt(E/W - yavg**2)
    yerr = ystd/np.sqrt(W)

    # Compute bin centers.
    xc = 0.5*(edges[1:] + edges[:-1])
    
    if uncertainty == 'sample':
        return xc, yavg, ystd
    elif uncertainty == 'stderr':
        return xc, yavg, yerr
    else:
        raise ValueError(f'uncertainty={uncertainty} unknown; allowed: "stderr" and "sample"')

# %% [markdown]
# # Profile Historgrams and Linear Regressions

# %% [markdown]
# ## Color (u-r

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_table['3D_neighbor_dist'][select]
    vals = dwarf_table['u_r'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,3,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.03, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='u-r', xlim=([0,2]), ylim=([-0.5,3]));
    ax.legend();

    fig.savefig('ur_3D_PH.png')

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_table['3D_neighbor_dist'][select]
    vals = dwarf_table['u_r'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.logspace(np.log10(0.05),np.log10(3),21), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.03, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='u-r', xlim=([0.05,3]), ylim=([-0.5,3]));
    ax.set_xscale('log') #changing x axis to a logarithmic scale

    ax.legend();

    fig.savefig('ur_3D_PH_log.png')

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_table['3D_neighbor_dist'][select]
    vals = dwarf_table['u_r'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.03, color=c, marker=m)
        
    xedges = np.linspace(0,3,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='u-r', xlim=(0,2), ylim=(-0.5,3));
        
    ax.legend()
        
    fig.savefig('ur_3D_LR.png')

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_table['3D_neighbor_dist'][select]
    vals = dwarf_table['u_r'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.03, color=c, marker=m)
    
    logbins = np.logspace(np.log10(0.05),np.log10(3),21) #making bins even logarithmicly  
    xcenters = 0.5*(logbins[1:] + logbins[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
          
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='u-r', xlim=(0.05,2), ylim=(-0.5,3));
    
    ax.set_xscale('log')
    
    ax.legend()
    
    fig.savefig('ur_3D_LR_log.png')

# %% [markdown]
# ## Star Formation Rate (sSFR)

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_table['3D_neighbor_dist'][select]
    vals = dwarf_table['sSFR'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,3,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.03, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='sSFR [$yr^{-1}]$', xlim=([0,2]), ylim=(-11.5,-8.5));
    ax.legend();

    fig.savefig('sSFR_3D_PH.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_table['3D_neighbor_dist'][select]
    vals = dwarf_table['sSFR'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.logspace(np.log10(0.03),np.log10(3),21), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.05, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='sSFR [$yr^{-1}]$', xlim=([0.05,3]), ylim=(-11.5,-8.5));
    ax.set_xscale('log') #changing x axis to a logarithmic scale

    ax.legend();

    fig.savefig('sSFR_3D_PH_log.png')

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_table['3D_neighbor_dist'][select]
    vals = dwarf_table['sSFR'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.03, color=c, marker=m)
        
    xedges = np.linspace(0,3,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='sSFR [$yr^{-1}]$', xlim=(0,2), ylim=(-11.5,-8.5));
        
    ax.legend()
        
    fig.savefig('sSFR_3D_LR.png')

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall, dwarf_void], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_table['3D_neighbor_dist'][select]
    vals = dwarf_table['sSFR'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.03, color=c, marker=m)
    
    logbins = np.logspace(np.log10(0.05),np.log10(3),21) #making bins even logarithmicly  
    xcenters = 0.5*(logbins[1:] + logbins[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
          
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='sSFR [$yr^{-1}]$', xlim=(0.05,2), ylim=(-11.5,-8.5));
    
    ax.set_xscale('log')
    
    ax.legend()
    
    fig.savefig('sSFR_3D_LR_log.png')

# %% [markdown]
# ## Metallicity (12 + log(O/H))

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['Z12logOH'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,3,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='12 + log(O/H)', xlim=([0,2]), ylim=(6.5,9));
    ax.legend();

    fig.savefig('Z12logOH_3D_PH.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['Z12logOH'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.logspace(np.log10(0.05),np.log10(3),21), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='12 + log(O/H)', xlim=([0.05,3]), ylim=(6.5,9));
    ax.set_xscale('log') #changing x axis to a logarithmic scale

    ax.legend();

    fig.savefig('Z12logOH_3D_PH_log.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['Z12logOH'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    xedges = np.linspace(0,3,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='12 + log(O/H)', xlim=(0,2), ylim=(7,8.7));
        
    ax.legend()
        
    fig.savefig('Z12logOH_3D_LR.png')

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['Z12logOH'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    
    logbins = np.logspace(np.log10(0.05),np.log10(3),21) #making bins even logarithmicly  
    xcenters = 0.5*(logbins[1:] + logbins[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
          
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='12 + log(O/H)', xlim=(0.05,2), ylim=(7,8.7));
    
    ax.set_xscale('log')
    
    ax.legend()
    
    fig.savefig('Z12logOH_3D_LR_log.png')

# %% [markdown]
# ## Metallicity Difference (target - neighbor)

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['3D_Z12logOH_diff'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,3,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='Δ12 + log(O/H) (target - neighbor)', xlim=([0,2]), ylim=(-1.5,2));
    ax.legend();

    fig.savefig('Z12logOH_diff_3D_PH.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['3D_Z12logOH_diff'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    xedges = np.linspace(0,3,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='Δ12 + log(O/H) (target - neighbor)', xlim=(0,2), ylim=(-1.5,2));
        
    ax.legend()
        
    fig.savefig('Z12logOH_diff_3D_LR.png')

# %% [markdown]
# ## N/O Ratio

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['logNO'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,3,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='log(N/O)', xlim=([0,2]), ylim=(-2,-0.8));
    ax.legend();

    fig.savefig('logNO_3D_PH.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['logNO'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.logspace(np.log10(0.05),np.log10(3),21), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='log(N/O)', xlim=([0.05,3]), ylim=(-2,-0.8));
    ax.set_xscale('log') #changing x axis to a logarithmic scale

    ax.legend();

    fig.savefig('logNO_3D_PH_log.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['logNO'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    xedges = np.linspace(0,3,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='log(N/O)', xlim=(0,2), ylim=(-2,-0.8));
        
    ax.legend()
        
    fig.savefig('logNO_3D_LR.png')

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['logNO'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    logbins = np.logspace(np.log10(0.05),np.log10(3),21) #making bins even logarithmicly  
    xcenters = 0.5*(logbins[1:] + logbins[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='log(N/O)',
           xlim=(0.05,2), ylim=(-2,-0.8));
    
    ax.set_xscale('log')
    
    ax.legend()
        
    fig.savefig('logNO_3D_LR_log.png')

# %% [markdown]
# ## N/O Ratio Difference (target - neighbor)

# %% [markdown]
# ### Profile Histogram

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
   
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['3D_logNO_diff'][select]
    nonan = ~np.isnan(vals)

    xc, yavg, yerr = profilehist(d[nonan], vals[nonan], bins=np.linspace(0,3,31), uncertainty='sample')
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
    ax.errorbar(xc, yavg, yerr=yerr, fmt='o', color=mc, label=label)

    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='Δlog(N/O) (target - neighbor)', xlim=([0,2]), ylim=(-1,0.5));
    ax.legend();

    fig.savefig('logNO_diff_3D_PH.png')
# Out:
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:32: RuntimeWarning: invalid value encountered in true_divide
#   yavg = Y/W
# C:\Users\caeho\AppData\Local\Temp\ipykernel_26920\2670135367.py:33: RuntimeWarning: invalid value encountered in true_divide
#   ystd = np.sqrt(E/W - yavg**2)

# %% [markdown]
# ### Linear Regression

# %%
fig, ax = plt.subplots(1,1, figsize=(6.4,4.8), tight_layout=True)

for select, mc, label, c, m in zip([dwarf_wall_t3, dwarf_void_t3], ['black', 'red'], ['wall', 'void'], ['k', 'r'], ['^', 'o']):
    
    d = dwarf_t3['3D_neighbor_dist'][select]
    vals = dwarf_t3['3D_logNO_diff'][select]
    nonan = ~np.isnan(vals)
       
    ax.scatter(d[nonan], vals[nonan], alpha=0.1, color=c, marker=m)
        
    xedges = np.linspace(0,3,31)
    xcenters = 0.5*(xedges[1:] + xedges[:-1])
        
    sns.regplot(x=d[nonan], y=vals[nonan], x_bins=xcenters, color=mc, ax=ax, label=label)
        
        
        
    ax.set(xlabel='Distance to Nearest Neighbor [$h^{-1}Mpc]$', ylabel='Δlog(N/O) (target - neighbor)', xlim=(0,2), ylim=(-1,0.5));
        
    ax.legend()
        
    fig.savefig('logNO_diff_3D_LR.png')
